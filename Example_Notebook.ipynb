# %%
# Valorant Agent Recommendation System

# %%
# 1. Import requirements

import pandas as pd
import joblib
from scripts.recommend import recommend_best_agent 
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
# Out:
# Map?  bind
# Team composition (comma separated, e.g., Jett,Sage,Reyna,Omen)?  jett,sage,reyna,omen
# \Recommended Agents:
# Logistic Regression: Phoenix (Predicted Win Probability: 53.54%)
# Random Forest: Yoru (Predicted Win Probability: 53.96%)
# XGBoost: Phoenix (Predicted Win Probability: 57.74%)

# %%
# 2. Load preprocessed data

DATA_PATH = "data/match_sample_preprocessed.csv"
df = pd.read_csv(DATA_PATH)
df.head()
# Out:
#    match_id       player       map      agent  kills  deaths  assists  damage  \
# 0         1  test_player  Fracture      Viper     16      14        8     206
# 1         2  test_player    Ascent  Brimstone     24      23       11     223
# 2         3  test_player   Corrode      Reyna     19      21        5     281
# 3         4  test_player    Sunset    Phoenix      7      22        4     293
# 4         5  test_player    Icebox      KAY/O     11      20       13     100
#
#    headshot_pct  map_encoded  ...  Raze  Reyna  Sage  Sova  Tejo  Veto  Viper  \
# 0          27.1            5  ...     0      0     1     0     0     0      0
# 1          26.1            1  ...     1      0     0     0     1     0      0
# 2          32.9            4  ...     0      0     0     0     1     0      0
# 3          23.4           11  ...     0      0     0     0     0     0      1
# 4          31.9            7  ...     0      0     1     0     0     0      0
#
#    Waylay  Yoru  win
# 0       0     1    1
# 1       0     0    1
# 2       0     0    0
# 3       0     1    1
# 4       0     0    1
#
# [5 rows x 34 columns]
