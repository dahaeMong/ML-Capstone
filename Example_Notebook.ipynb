# %%
# Valorant Agent Recommendation System

# %%
# 1. Import requirements

import pandas as pd
import joblib
from scripts.recommend import recommend_best_agent 
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
# 2. Load preprocessed data

DATA_PATH = "data/match_sample_preprocessed.csv"
df = pd.read_csv(DATA_PATH)
df.head()

# %%
# 3. Load trained models.
models = {
    "logistic_regression": joblib.load("models/logistic_regression.pkl"),
    "random_forest": joblib.load("models/random_forest.pkl"),
    "xgboost": joblib.load("models/xgboost.pkl")
}

print("Models loaded!")

# %%
# 4. Test recommendation
# User input example
current_map = "Bind"
current_team_agents = ["Jett", "Sage", "Reyna", "Omen"]

# Recommended result
for name, model in models.items():
    agent, win_prob = recommend_best_agent(df, model, current_map, current_team_agents)
    print(f"{name}: Recommended Agent → {agent}, Predicted Win Probability: {win_prob*100:.2f}%")
